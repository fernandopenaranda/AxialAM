# %%
include("/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Packages/AxialAM/src/AxialAM.jl")
using AxialAM
using BZpaths
# Out:
# WARNING: replacing module AxialAM.
# ERROR: LoadError: ArgumentError: Package AxialAM does not have LinearAlgebra in its dependencies:
# - You may have a partially installed environment. Try `Pkg.instantiate()`
#   to ensure all packages in the environment are installed.
# - Or, if you have AxialAM checked out for development and have
#   added LinearAlgebra as a dependency but haven't updated your primary
#   environment's manifest file, try `Pkg.resolve()`.
# - Otherwise you may need to report an issue with AxialAM
# Stacktrace:
#  [1] macro expansion
#    @ ./loading.jl:1634 [inlined]
#  [2] macro expansion
#    @ ./lock.jl:267 [inlined]
#  [3] require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:1611
#  [4] include
#    @ ./Base.jl:457 [inlined]
#  [5] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
# ...

# %%
# function promote3d!(vecs)
#     for vec in vecs
#         append!(vec, [0.])
#     end
# end
# Out:
# promote3d! (generic function with 1 method)

# %%
a0 = 1
Rs = lattice_vectors(a0)     # Lattice vectors, can be 2d or 3d
# high_sym_line = [:M, :Γ]            # Custom k-path over high symmetry momenta
sgnum = 17                               # point group
N = 100                            # points in the k-mesh
# Out:
# UndefVarError: `lattice_vectors` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Documents/Work/PostdocDonosti/Packages/AxialAM/docs/AM_working_file.ipynb:2

# %%
kp = kpath(Rs, sgnum, N);
plot_kpath(Rs, sgnum, N)

# %%
using Brillouin
using LinearAlgebra
using Bravais

# %%
kp = irrfbz_path(sgnum, Rs)
# Out:
# KPath{2} (3 points, 1 paths, 4 points in paths):
#  points: :M => [0.5, 0.0]
#          :K => [0.333333, 0.333333]
#          :Γ => [0.0, 0.0]
#   paths: [:Γ, :M, :K, :Γ]
#   basis: [6.283185, -0.0]
#          [-0.0, 6.283185]
